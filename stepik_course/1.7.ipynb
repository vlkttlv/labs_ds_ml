# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_perfomance = pd.read_csv('datasets/StudentsPerformance.csv')

# %%
students_perfomance.math_score.hist()
# Out:
# <Axes: >

# %%
students_perfomance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=students_perfomance, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %% [markdown]
# Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.

# %%
df = pd.read_csv('datasets/dataset_209770_6.txt', delimiter=" ")

# %%
# df.plot.scatter(x='x', y='y')

sns.scatterplot(data=df, x='x', y='y') # 4
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
genome_matrix = pd.read_csv('datasets/genome_matrix.csv')
genome_matrix = genome_matrix.drop('Unnamed: 0', axis=1)

# %%
# постройте тепловую карту, чтобы различия было видно наглядно
grafik = sns.heatmap(data=genome_matrix, cmap='viridis')
grafik.xaxis.set_ticks_position('top')
grafik.xaxis.set_tick_params(rotation=90)

# %% [markdown]
# посмотрите на распределение их возможных ролей в игре (колонка roles). Постройте гистограмму, отражающую скольким героям сколько ролей приписывается (по мнению Valve, конечно) и напишите какое число ролей у большинства героев.
#
# Это задание можно выполнить многими путями, и рисовать гистограмму вообще говоря для этого не нужно.

# %%
dota_hero_stats = pd.read_csv('datasets/dota_hero_stats.csv')

# %%
dota_hero_stats['len_roles'] = dota_hero_stats.roles.str.split(',').str.len()

# %%
dota_hero_stats.len_roles.mode()
# или так
# dota_hero_stats.hist('len_roles')
# Out:
# 0    4
# Name: len_roles, dtype: int64

# %% [markdown]
#  скачайте датасэт со значениями параметров ирисов, постройте их распределения и отметьте правильные утверждения, глядя на график.

# %%
iris = pd.read_csv('datasets/iris.csv').drop('Unnamed: 0', axis=1)

# %%
for column in iris:
    sns.kdeplot(data=iris)
# answer:
# Petal length имеет наибольший размах значений
# Sepal width и sepal length имеют унимодальное распределение
# Petal width и petal length имеют бимодальное распределение

# %%
sns.violinplot(data=iris, y='petal length')
# Out:
# <Axes: ylabel='petal length'>

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000
